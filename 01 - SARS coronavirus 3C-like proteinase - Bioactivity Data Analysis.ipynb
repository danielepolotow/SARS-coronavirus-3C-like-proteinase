# %% [markdown]
# # 1 - SARS coronavirus 3C-like proteinase - Bioactivity Data Analysis

# %% [markdown]
# The 3C-like protease (3CLpro) or Mpro, formally known as C30 Endopeptidase, is the main protease found in coronaviruses. It cleaves the coronavirus polyprotein at eleven conserved sites. It is a cysteine protease and a member of the PA clan of proteases. It has a cysteine-histidine catalytic dyad at its active site and cleaves a Gln–(Ser/Ala/Gly) peptide bond.

# %% [markdown]
# The protease 3CLpro is a potential drug target for coronavirus infections due to its essential role in processing the polyproteins that are translated from the viral RNA. The X-ray structures of the unliganded SARS-CoV-2 protease 3CLpro and its complex with an α-ketoamide inhibitor provides a basis for design of α-ketoamide inhibitors for a treatment of SARS-CoV-2 infection.

# %% [markdown]
# In this project, I'm going to explore the ChEMBL database and analyse data related to SARS coronavirus 3C-like proteinase.

# %% [markdown]
# ### ChEMBL Database

# %% [markdown]
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications. [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# https://www.ebi.ac.uk/chembl/

# %% [markdown]
# ### Installing libraries

# %% [markdown]
# Installing the ChEMBL web service package to retrieve bioactivity data from the ChEMBL Database.

# %%
#!pip install chembl_webresource_client

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
from chembl_webresource_client.new_client import new_client

# %%
pd.options.display.max_columns = None
#pd.options.display.max_rows = None

# %% [markdown]
# ### Search for Target protein

# %% [markdown]
# Target search for coronavirus

# %%
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 7                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
# 7    Severe acute respiratory syndrome coronavirus 2
#
# ...

# %% [markdown]
# - I'm going to use the first single protein (in 'target_type') for this notebook.

# %% [markdown]
# ### Select and retrieve bioactivity data for SARS coronavirus 3C-like proteinase (fifth entry)

# %% [markdown]
# I will assign the fifth entry (which corresponds to the target protein, coronavirus 3C-like proteinase) to the selected_target variable

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# Now, I will retrieve only bioactivity data for coronavirus 3C-like proteinase (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      1480935                  []    CHEMBL829584
# 1               None      1480936                  []    CHEMBL829584
# 2               None      1481061                  []    CHEMBL830868
# 3               None      1481065                  []    CHEMBL829584
# 4               None      1481066                  []    CHEMBL829584
# ..               ...          ...                 ...             ...
# 128             None     12041507                  []   CHEMBL2150313
# 129             None     12041508                  []   CHEMBL2150313
# 130             None     12041509                  []   CHEMBL2150313
# 131             None     12041510                  []   CHEMBL2150313
# 132             None     12041511                  []   CHEMBL2150313
#
#                                      assay_description assay_type  \
# ...

# %% [markdown]
# Main goals with this filter:
# - find molecules with the same bioactivity unit types (in this case = standard_type="IC50"), or 50% inibition of the target protein.
# - find molecules wiht a lower 'standard_value' feature; the standard value describe the potency of the drug; the lower the number, better the potency of the drug.
# - a lower 'standard_value' means in order to elicit 50% of the inibition of a target protein, you will need lower concentration of the drug.
# - It is always better to have a drug that works in lower concentrations. Otherwise, you will need more drug to get the same 50% inibition of the target protein.

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %%
df.target_chembl_id.unique()
# Out:
# array(['CHEMBL3927'], dtype=object)

# %% [markdown]
# - Finally, I will save the resulting bioactivity data to a CSV file bioactivity_data.csv.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## Handling missing data

# %%
# reading the saved file
df = pd.read_csv('bioactivity_data.csv')
df
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                 NaN      1480935                  []    CHEMBL829584
# 1                 NaN      1480936                  []    CHEMBL829584
# 2                 NaN      1481061                  []    CHEMBL830868
# 3                 NaN      1481065                  []    CHEMBL829584
# 4                 NaN      1481066                  []    CHEMBL829584
# ..                ...          ...                 ...             ...
# 128               NaN     12041507                  []   CHEMBL2150313
# 129               NaN     12041508                  []   CHEMBL2150313
# 130               NaN     12041509                  []   CHEMBL2150313
# 131               NaN     12041510                  []   CHEMBL2150313
# 132               NaN     12041511                  []   CHEMBL2150313
#
#                                      assay_description assay_type  \
# ...

# %% [markdown]
# Checking for missing data:

# %%
df.isna().any().any()
# Out:
# True

# %% [markdown]
# Counting the missing data:

# %%
df.isna().sum().sum()
# Out:
# 1491

# %% [markdown]
# Listing the features with missing data:

# %%
df.loc[:, df.isnull().any()].columns
# Out:
# Index(['activity_comment', 'assay_variant_accession', 'assay_variant_mutation',
#        'data_validity_comment', 'data_validity_description',
#        'ligand_efficiency', 'molecule_pref_name', 'pchembl_value',
#        'standard_text_value', 'standard_upper_value', 'text_value', 'toid',
#        'units', 'upper_value'],
#       dtype='object')

# %% [markdown]
# - no missing data in the standard_value feature.

# %%
np.where(pd.isnull(df))
# Out:
# (array([  0,   0,   0, ..., 132, 132, 132], dtype=int64),
#  array([ 0,  6,  7, ..., 38, 39, 43], dtype=int64))

# %% [markdown]
# If any compounds has missing value for the standard_value column then drop it:

# %%
df = df[df.standard_value.notna()]

# %% [markdown]
# - No missing data in this dataset in the standard_value column, but we are keeping this code for other data analysis.

# %% [markdown]
# ## Data pre-processing of the bioactivity data¶

# %% [markdown]
# ### Labeling compounds as either being active, inactive or intermediate

# %% [markdown]
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be active while those greater than 10,000 nM will be considered to be inactive. As for those values in between 1,000 and 10,000 nM will be referred to as intermediate.
#
# The next loop will classify the molecules accoding to the standard_value:

# %%
bioactivity_class = []
for i in df.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### Iterate the molecule_chembl_id to a list

# %%
mol_cid = []
for i in df.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### Iterate canonical_smiles to a list

# %%
canonical_smiles = []
for i in df.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### Iterate standard_value to a list

# %%
standard_value = []
for i in df.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### Combine the 4 lists into a dataframe

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df1 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df1
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     bioactivity_class  standard_value
# 0        intermediate          7200.0
# ...

# %% [markdown]
# ### Alternative method

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df2 = df[selection]
df2
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#      standard_value
# 0            7200.0
# 1            9400.0
# ...

# %%
df2 = pd.concat([df2,pd.Series(bioactivity_class)], axis=1)
df2
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#      standard_value             0
# 0            7200.0  intermediate
# ...

# %%
df3 = df2.rename(columns = {0: 'bioactivity_class'}, inplace = False)
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#      standard_value bioactivity_class
# 0            7200.0      intermediate
# ...

# %% [markdown]
# ### Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)
